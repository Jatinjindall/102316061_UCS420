# %% [markdown]
# ##__Assignment 7 CC by Jatin Jindal (102316061).__

# %% [markdown]
# ##Question 1: You are a data analyst at an e-commerce company. Your task is to analyze sales data, clean and process it, perform statistical analysis, and generate visual insights to help the business make informed decisions.
# 1. Use your roll number as the random seed to generate unique data for each student.
# 2. Follow the questions step by step, as each part builds upon the previous one.
# 3. Submit the assignment as a Jupyter Notebook (.ipynb) with:
#  Well-documented code and clear comments.
#  Markdown explanaƟons for each step.
#  Screenshots of the plots and outputs

# %% [markdown]
# ##### Part I: Randomized Sales Data Generation
# ##### Step 1: Initialize Random Seed
# Use your roll number as the random seed to ensure unique data.

# %%
import numpy as np

# Replace with your roll number
roll_number = 12345
np.random.seed(roll_number)

# %% [markdown]
# ##### Step 2: Generate Sales Data
# Create a 12x4 NumPy array where each column represents sales data for a product category.

# %%
sales_data = np.random.randint(1000, 5001, size=(12, 4))
print("Generated Sales Data:")
print(sales_data)
# Out:
# Generated Sales Data:
# [[1482 4557 4357 3177]
#  [4492 4497 1382 4429]
#  [1546 4613 3817 4190]
#  [4441 4387 3702 3153]
#  [4163 3807 2398 4280]
#  [1882 1713 1267 4149]
#  [2674 1081 2746 3214]
#  [3311 1043 1231 1023]
#  [2053 4000 4511 2311]
#  [1701 1353 2883 1855]
#  [3084 3624 1387 3812]
#  [2148 2669 4215 1631]]

# %% [markdown]
# ##### Step 3: Convert Data to DataFrame
# Convert the generated NumPy array into a Pandas DataFrame with appropriate labels.

# %%
import pandas as pd

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
categories = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]
sales_df = pd.DataFrame(sales_data, columns=categories, index=months)
print(sales_df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1482      4557            4357    3177
# Feb         4492      4497            1382    4429
# Mar         1546      4613            3817    4190
# Apr         4441      4387            3702    3153
# May         4163      3807            2398    4280
# Jun         1882      1713            1267    4149
# Jul         2674      1081            2746    3214
# Aug         3311      1043            1231    1023
# Sep         2053      4000            4511    2311
# Oct         1701      1353            2883    1855
# Nov         3084      3624            1387    3812
# Dec         2148      2669            4215    1631

# %% [markdown]
# #### Part II: Data Manipulation and Analysis
# ##### Step 1: Display the First 5 Rows and Summary Statistics.

# %%
print(sales_df.head())
print(sales_df.describe())
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1482      4557            4357    3177
# Feb         4492      4497            1382    4429
# Mar         1546      4613            3817    4190
# Apr         4441      4387            3702    3153
# May         4163      3807            2398    4280
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2748.083333  3112.000000     2824.666667  3102.000000
# std    1131.455254  1448.254184     1285.766085  1152.870252
# min    1482.000000  1043.000000     1231.000000  1023.000000
# 25%    1836.750000  1623.000000     1385.750000  2197.000000
# 50%    2411.000000  3715.500000     2814.500000  3195.500000
# 75%    3524.000000  4414.500000     3916.500000  4159.250000
# max    4492.000000  4613.000000     4511.000000  4429.000000

# %% [markdown]
# ##### Step 2: Calculate Total Sales Per Category and Month.

# %%
sales_df["Total Sales"] = sales_df.sum(axis=1)
print(sales_df["Total Sales"])
# Out:
# Jan    13573
# Feb    14800
# Mar    14166
# Apr    15683
# May    14648
# Jun     9011
# Jul     9715
# Aug     6608
# Sep    12875
# Oct     7792
# Nov    11907
# Dec    10663
# Name: Total Sales, dtype: int64

# %% [markdown]
# ##### Step 3: Calculate Average Sales Growth Between Consecutive Months.

# %%
sales_growth = sales_df.diff().mean()
print(sales_growth)
# Out:
# Electronics        60.545455
# Clothing         -171.636364
# Home & Kitchen    -12.909091
# Sports           -140.545455
# Total Sales      -264.545455
# dtype: float64

# %% [markdown]
# ##### Step 4: Add Growth Rate Column.

# %%
sales_df["Growth Rate"] = sales_df["Total Sales"].pct_change() * 100
print(sales_df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         1482      4557            4357    3177        13573          NaN
# Feb         4492      4497            1382    4429        14800     9.040006
# Mar         1546      4613            3817    4190        14166    -4.283784
# Apr         4441      4387            3702    3153        15683    10.708739
# May         4163      3807            2398    4280        14648    -6.599503
# Jun         1882      1713            1267    4149         9011   -38.483069
# Jul         2674      1081            2746    3214         9715     7.812673
# Aug         3311      1043            1231    1023         6608   -31.981472
# Sep         2053      4000            4511    2311        12875    94.839588
# Oct         1701      1353            2883    1855         7792   -39.479612
# Nov         3084      3624            1387    3812        11907    52.810575
# ...

# %% [markdown]
# ##### Step 5: Apply a Randomized Discount Based on Roll Number.

# %%
if roll_number % 2 == 0:
sales_df["Electronics"] *= 0.9  # 10% discount
else:
sales_df["Clothing"] *= 0.85  # 15% discount
print(sales_df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         1482   3873.45            4357    3177        13573          NaN
# Feb         4492   3822.45            1382    4429        14800     9.040006
# Mar         1546   3921.05            3817    4190        14166    -4.283784
# Apr         4441   3728.95            3702    3153        15683    10.708739
# May         4163   3235.95            2398    4280        14648    -6.599503
# Jun         1882   1456.05            1267    4149         9011   -38.483069
# Jul         2674    918.85            2746    3214         9715     7.812673
# Aug         3311    886.55            1231    1023         6608   -31.981472
# Sep         2053   3400.00            4511    2311        12875    94.839588
# Oct         1701   1150.05            2883    1855         7792   -39.479612
# Nov         3084   3080.40            1387    3812        11907    52.810575
# ...

# %% [markdown]
# #### Part III: Data Visualization
# ##### Step 1: Monthly Sales Trends (Line Plot)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
for category in categories:
plt.plot(sales_df.index, sales_df[category], marker='o', label=category)
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### Step 2: Sales Distribution (Box Plot)

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=sales_df[categories])
plt.title("Sales Distribution by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# #### Question 2: For the array: array = np.array([[1, -2, 3],[-4, 5, -6]]).
#  i. Find element-wise absolute value
# ii. Find the 25th, 50th, and 75th percenƟle of flattened array, for each column, for each row.
# iii. Mean, Median and Standard Deviation of flattened array, of each column, and
# each row

# %%
array = np.array([[1, -2, 3], [-4, 5, -6]])
abs_array = np.abs(array)
print(abs_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ##### Step 2: Compute 25th, 50th, 75th Percentile

# %%
percentiles = np.percentile(array, [25, 50, 75], axis=None)
print(percentiles)
# Out:
# [-3.5 -0.5  2.5]

# %% [markdown]
# ##### Step 3: Compute Mean, Median, and Standard Deviation.

# %%
mean_flat = np.mean(array)
median_flat = np.median(array)
std_flat = np.std(array)
print(mean_flat, median_flat, std_flat)
# Out:
# -0.5 -0.5 3.8622100754188224

# %% [markdown]
# #### Question 3: For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).
#  i. Find floor, ceiling and truncated value, rounded values.

# %%
arr = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print("Floor:", np.floor(arr))
print("Ceiling:", np.ceil(arr))
print("Truncated:", np.trunc(arr))
print("Rounded:", np.round(arr))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# #### Question 4: WAP to swap two elements in a list in Python Using a Temporary Variable

# %%
lst = [1, 2, 3, 4, 5]
i, j = 1, 3
print("Before Swap:", lst)
temp = lst[i]
lst[i] = lst[j]
lst[j] = temp
print("After Swap:", lst)
# Out:
# Before Swap: [1, 2, 3, 4, 5]
# After Swap: [1, 4, 3, 2, 5]

# %% [markdown]
# ##Question 5: Write a Python program to swap two elements in a set by converƟng it to a list first

# %%
s = {10, 20, 30, 40, 50}
s_list = list(s)
s_list[1], s_list[3] = s_list[3], s_list[1]
s_swapped = set(s_list)
print("Swapped Set:", s_swapped)
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
